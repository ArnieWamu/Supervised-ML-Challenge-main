# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel

# %%
train_df = pd.read_csv(Path(r'C:\Users\arnol\Downloads\Supervised-ML-Challenge-main\Supervised-ML-Challenge-main\Resources\2019loans.csv'))
test_df = pd.read_csv(Path(r'C:\Users\arnol\Downloads\Supervised-ML-Challenge-main\Supervised-ML-Challenge-main\Resources\2020Q1loans.csv'))

# %%
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
# ...

# %%
train_df.describe()
# Out:
#           Unnamed: 0          index     loan_amnt      int_rate   installment  \
# count   12180.000000   12180.000000  12180.000000  12180.000000  12180.000000
# mean   187893.694745  187893.694745  17399.579228      0.140899    509.150241
# std     99710.342179   99710.342179  10238.160884      0.052679    294.617726
# min        24.000000      24.000000   1000.000000      0.060000     30.890000
# 25%    104269.250000  104269.250000  10000.000000      0.103300    286.902500
# 50%    190128.000000  190128.000000  15000.000000      0.130800    438.530000
# 75%    274595.750000  274595.750000  25000.000000      0.177400    682.230000
# max    355312.000000  355312.000000  40000.000000      0.308400   1671.880000
#
#          annual_inc           dti   delinq_2yrs  inq_last_6mths      open_acc  \
# count  1.218000e+04  12180.000000  12180.000000    12180.000000  12180.000000
# mean   8.989320e+04     22.589516      0.256979        0.566502     12.680296
# ...

# %%
train_df.dtypes
# Out:
# Unnamed: 0                      int64
# index                           int64
# loan_amnt                     float64
# int_rate                      float64
# installment                   float64
#                                ...
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# debt_settlement_flag           object
# Length: 86, dtype: object

# %%
# Convert categorical data to numeric and separate target feature for training data
X = train_df.drop('loan_status', axis=1)
X
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0           57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1          141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2          321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3           11778   11778     3000.0    0.1240       100.22           RENT
# 4          169382  169382    30000.0    0.1612      1056.49       MORTGAGE
# ...           ...     ...        ...       ...          ...            ...
# 12175      354912  354912    19975.0    0.2565       801.09           RENT
# 12176      354944  354944    15000.0    0.1774       540.34           RENT
# 12177      354973  354973     3600.0    0.1862       131.28           RENT
# 12178      355002  355002    15000.0    0.0881       475.68       MORTGAGE
# 12179      355307  355307    15000.0    0.1774       540.34           RENT
#
# ...

# %%
pd.get_dummies(X['home_ownership'])
# Out:
#        ANY  MORTGAGE  OWN  RENT
# 0        0         1    0     0
# 1        0         1    0     0
# 2        0         1    0     0
# 3        0         0    0     1
# 4        0         1    0     0
# ...    ...       ...  ...   ...
# 12175    0         0    0     1
# 12176    0         0    0     1
# 12177    0         0    0     1
# 12178    0         1    0     0
# 12179    0         0    0     1
#
# [12180 rows x 4 columns]

# %%
X_dummies = pd.get_dummies(X)
print(X_dummies.columns)
X_dummies
# Out:
# Index(['Unnamed: 0', 'index', 'loan_amnt', 'int_rate', 'installment',
#        'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
y_label = LabelEncoder().fit_transform(train_df['loan_status'])
y_label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=1)

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression().fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.6535303776683087
# Testing Score: 0.6463054187192119
# C:\Users\arnol\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# array([[-0.65414693, -0.65414693, -1.21011981, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 1.5929921 ,  1.5929921 , -1.327905  , ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 0.83663139,  0.83663139, -1.21011981, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        ...,
#        [ 0.41312268,  0.41312268,  0.16404075, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 1.67466527,  1.67466527, -0.22857655, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 0.13666574,  0.13666574,  0.85112103, ..., -0.1694586 ,
#          0.01812499, -0.01812499]])

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.5050903119868637
# Testing Score: 0.5146141215106732

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-0.86884072, -0.86884072,  0.26219508, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [-0.97142543, -0.97142543,  0.75296671, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [-1.77412602, -1.77412602,  1.07196827, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        ...,
#        [ 0.5308302 ,  0.5308302 , -0.52303953, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 0.78356135,  0.78356135,  0.26219508, ..., -0.1694586 ,
#          0.01812499, -0.01812499],
#        [ 1.02208108,  1.02208108, -0.71934818, ..., -0.1694586 ,
#          0.01812499, -0.01812499]])

# %%
# Train the Logistic Regression model on the scaled data and print the model score

clf = LogisticRegression().fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 0.6348111658456486
# Testing Score: 0.6216748768472906
# C:\Users\arnol\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.7944170771756979
